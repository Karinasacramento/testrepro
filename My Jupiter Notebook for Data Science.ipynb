# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Karina Sacramento**
# Data Engineer

# %% [markdown]
# _I am interested in data science because it helps to analyse company data and adding value to my job_

# %% [markdown]
# ### Next code is supposed to sum

# %%
1+1
# Out:
# 2

# %% [markdown]
# |number|name|last name|
# |------|------|------|
# |1|Fernando|Feijo|
# |2|Karina|Thiebaut|
#
# Week days:
#  - Monday
#  - Tuesday
#  - Wednesday
#  - Thursday
#  - Friday
#
# Top 3 things I like to do:
# 1. Travel
# 1. Hang out with friends
# 1. Watch movies
#
# I ~~don't~~ like to travel
#
# I <mark>do</mark> like to read books
